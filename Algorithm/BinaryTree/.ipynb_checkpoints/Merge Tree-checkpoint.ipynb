# %%
def mergeTrees(t1, t2):

    if not t1:
        return t2
    if not t2:
        return t1
    
    def sumTree(lTree, rTree):
        print('sumTree')
        c_val = 0
        if not lTree and not rTree:
            return None
        
        if lTree and rTree:
            print(lTree.val, rTree.val)
            c_val =+ lTree.val + rTree.val
        elif not lTree:
            print('000', rTree.val)
            c_val += rTree.val
        elif not rTree:
            print(lTree.val, '000')
            c_val += lTree.val
          
        
        print('--->', c_val)
        return c_val
    
    def createTree(lTree, rTree):
    
        if not lTree and not lTree:
            return None
        
        return_tree = TreeNode(sumTree(lTree, rTree))
        
        if lTree:
            if rTree:
                return_tree.left = createTree(lTree.left, rTree.left)
                return_tree.right = createTree(lTree.right, rTree.right)
            else:
                return_tree.left = createTree(lTree.left, None)
                return_tree.right = createTree(lTree.right, None)
    
        else:
            if rTree:
                return_tree.left = createTree(None, rTree.left)
                return_tree.right = createTree(None, rTree.right)
            else:
                return_tree.left = None
                return_tree.right = None
        
        print('createTree', sumTree(lTree, rTree))
        print_btree(return_tree)
        return return_tree
        
    r_tree = createTree(t1, t2)
    
    
    
    return r_tree

# %%
t1 = TreeNode(3)
t13 = TreeNode(3)
t15 = TreeNode(5)
t17 = TreeNode(7)

t1.left = TreeNode(3)
t1.right = t15
t15.right = t17
t15.left = TreeNode(1)
t17.right = TreeNode(9)



t2 = TreeNode(2)
t24 = TreeNode(4)
t26 = TreeNode(6)

t2.left = t24 
t24.left = TreeNode(8)
t24.right = t26


print_btree(t1)
print_btree(t2)

r = mergeTrees(t1, t2)
print('=======')
print_btree(r)
# Out:
# 3
# 3 5
# - - 1 7
# - - - 9
# - -
# 2
# 4 -
# 8 6
# - - - -
# sumTree
# 3 2
# ---> 5
# sumTree
# 3 4
# ---> 7
# sumTree
# 3 4
# ---> 7
# createTree 7
# 7
# - -
# sumTree
# 5 000
# ---> 5
# sumTree
# 1 000
# ---> 1
# sumTree
# 1 000
# ---> 1
# createTree 1
# 1
# - -
# sumTree
# 7 000
# ---> 7
# sumTree
# 9 000
# ---> 9
# sumTree
# 9 000
# ---> 9
# createTree 9
# 9
# - -
# sumTree
# 7 000
# ---> 7
# createTree 7
# 7
# - 9
# - -
# sumTree
# 5 000
# ---> 5
# createTree 5
# 5
# 1 7
# - - - 9
# - -
# sumTree
# 3 2
# ---> 5
# createTree 5
# 5
# 7 5
# - - 1 7
# - - - 9
# - -
# =======
# 5
# 7 5
# - - 1 7
# - - - 9
# - -
