# %%
"""

Container With Most Water

Input: [1,8,6,2,5,4,8,3,7]
Output: 49

"""

def maxArea(height):
    if height == 2:
        return min(height[0], height[1])
    max_water 0

    l = 0
    r = 1

# %%
def validSudoku(board):
    big = set()
    for i in range(0, 9):
        for j in range(0, 9):
            if board[i][j] != '.':
                cur = board[i][j]

                if (i, cur) in big or (cur, j) in big or (i // 3, j // 3, cur) in big:
                    return False
                big.add((i, cur))
                big.add((cur, j))

                big.add((i // 3, j // 3, cur))
    print(big)
    return True

# test
a1 = [
  ["5","3",".",".","7",".",".",".","."],
  ["6",".",".","1","9","5",".",".","."],
  [".","9","8",".",".",".",".","6","."],
  ["8",".",".",".","6",".",".",".","3"],
  ["4",".",".","8",".","3",".",".","1"],
  ["7",".",".",".","2",".",".",".","6"],
  [".","6",".",".",".",".","2","8","."],
  [".",".",".","4","1","9",".",".","5"],
  [".",".",".",".","8",".",".","7","9"]
]
print(validSudoku(a1))
# Out:
# {(1, 0, '7'), ('8', 0), ('6', 1), (2, '9'), (8, '8'), (2, '6'), ('1', 3), (1, '1'), (0, '7'), (1, '6'), ('2', 4), (2, 2, '8'), (2, '8'), ('4', 0), (4, '4'), (2, 1, '1'), (8, '9'), (1, 2, '6'), (2, 1, '4'), (1, 1, '2'), (0, 0, '6'), (0, 1, '5'), ('9', 4), ('4', 3), (1, 0, '4'), (3, '8'), ('6', 0), (0, 0, '8'), ('3', 5), (5, '7'), (6, '2'), (5, '2'), (7, '1'), ('1', 4), (1, 2, '1'), (3, '3'), (4, '1'), ('8', 2), (6, '6'), (3, '6'), ('5', 8), (4, '3'), ('8', 7), (0, 1, '7'), (1, 2, '3'), (5, '6'), (0, 0, '3'), (0, 1, '9'), ('2', 6), (6, '8'), ('6', 4), (7, '4'), ('9', 5), ('3', 1), (4, '8'), ('1', 8), (1, '5'), ('7', 0), ('6', 7), (0, 2, '6'), (0, '5'), (2, 0, '6'), (1, 1, '8'), (2, 2, '9'), ('8', 3), (2, 2, '2'), (2, 2, '7'), (7, '9'), (1, '9'), (0, 1, '1'), (1, 1, '6'), (8, '7'), ('7', 7), ('8', 4), ('9', 1), ('3', 8), (0, '3'), ('5', 5), ('7', 4), (0, 0, '9'), ('6', 8), (7, '5'), (0, 0, '5'), (2, 1, '8'), ('5', 0), (2, 1, '9'), ('9', 8), (1, 1, '3'), (2, 2, '5'), (1, 0, '8')}
# True
