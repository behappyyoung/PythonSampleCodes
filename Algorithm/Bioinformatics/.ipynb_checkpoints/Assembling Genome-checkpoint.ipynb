# %%
"""
    Input:
AAC
ACG
GAA
GTT
TCG

Output:
ACGTTCGA


Explanation:
In this sample, the circular genome is ACGTTCGA (the sample output), and the reads were
all generated from the genome: 
"AC"GTTCG"A", "ACG"TTCGA, "A"CGTTC"GA", AC"GTT"CGA, and ACGT"TCG"A.


    
"""
from collections import defaultdict

# class ListNode:
#     def __init__(self, i, x):
#         self.val = x
#         self.index = i
#         self.next = None

#     def val_exist(self, head_node, val):
#         c_node = head_node
#         while c_node is not None:
#             if c_node.val == val:
#                 return True
#             c_node = c_node.next
#         return False
    
# def print_node(head_node):
#     c_node = head_node
#     print_str = ''
#     while c_node is not None:
#         print_str += '->' + str(c_node.val)
#         c_node = c_node.next
#     print(print_str)

def gen_overlap(arr):
    l_arr = len(arr)
    l_str = len(arr[0])
    overlap_dict = defaultdict()
    for out_arr in arr:
        for in_arr in arr:
            for i in range(1, l_arr-2):
                if out_arr != in_arr:
                    if out_arr[i:] == in_arr[:l_str-i]:
                           
                        if out_arr in overlap_dict:
                            overlap_dict[out_arr][in_arr] =  l_str-i
                        else:
                            overlap_dict[out_arr] = {in_arr: l_str-i}
#                         print(i, out_arr[i:], in_arr[:l_str-i], overlap_dict)
    return overlap_dict
    

def next_key(c_dict, visited):
    for d in c_dict:
        for dd in c_dict[d]:
            if c_dict[d][dd] != 0 and d not in visited:
                return d
    return None

def next_inner_key(c_dict, visited):
    for d in c_dict:
        if c_dict[d] != 0 and d not in visited:
            return d
    return None

def gen_string(graph_dict):
    
    prev_key = next(iter(graph_dict))
    return_str = prev_key
    visited = [prev_key]
    done = False
    total_overlap = 0
    
    while prev_key:
        c_key = next_inner_key(graph_dict[prev_key], visited)
        if c_key:
            visited.append(c_key)
            overlap = graph_dict[prev_key][c_key]
            total_overlap += overlap
            return_str += c_key[overlap:]
            graph_dict[prev_key][c_key] = 0
            prev_key = c_key
        else:
            if len(arr) == len(visited):
                return return_str
            else:
                prev_key =  next_key(graph_dict, visited)
#             prev_key = None
            
        print('copy_dict', graph_dict, prev_key, c_key, return_str, visited)
        
        
    return return_str


def gen_genome(arr):
    
    graph_dict = gen_overlap(arr)
    
    print(graph_dict)
    
    r = gen_string(graph_dict)
    print(r)
    
arr = ['AAC', 'ACG', 'GAA', 'GTT', 'TCG']

gen_genome(arr)
# Out:
# defaultdict(None, {'AAC': {'ACG': 2}, 'ACG': {'GAA': 1, 'GTT': 1}, 'GAA': {'AAC': 1, 'ACG': 1}, 'GTT': {'TCG': 1}, 'TCG': {'GAA': 1, 'GTT': 1}})
# copy_dict defaultdict(None, {'AAC': {'ACG': 0}, 'ACG': {'GAA': 1, 'GTT': 1}, 'GAA': {'AAC': 1, 'ACG': 1}, 'GTT': {'TCG': 1}, 'TCG': {'GAA': 1, 'GTT': 1}}) ACG ACG AACG ['AAC', 'ACG']
# copy_dict defaultdict(None, {'AAC': {'ACG': 0}, 'ACG': {'GAA': 0, 'GTT': 1}, 'GAA': {'AAC': 1, 'ACG': 1}, 'GTT': {'TCG': 1}, 'TCG': {'GAA': 1, 'GTT': 1}}) GAA GAA AACGAA ['AAC', 'ACG', 'GAA']
# copy_dict defaultdict(None, {'AAC': {'ACG': 0}, 'ACG': {'GAA': 0, 'GTT': 1}, 'GAA': {'AAC': 1, 'ACG': 1}, 'GTT': {'TCG': 1}, 'TCG': {'GAA': 1, 'GTT': 1}}) GTT None AACGAA ['AAC', 'ACG', 'GAA']
# copy_dict defaultdict(None, {'AAC': {'ACG': 0}, 'ACG': {'GAA': 0, 'GTT': 1}, 'GAA': {'AAC': 1, 'ACG': 1}, 'GTT': {'TCG': 0}, 'TCG': {'GAA': 1, 'GTT': 1}}) TCG TCG AACGAACG ['AAC', 'ACG', 'GAA', 'TCG']
# copy_dict defaultdict(None, {'AAC': {'ACG': 0}, 'ACG': {'GAA': 0, 'GTT': 1}, 'GAA': {'AAC': 1, 'ACG': 1}, 'GTT': {'TCG': 0}, 'TCG': {'GAA': 1, 'GTT': 0}}) GTT GTT AACGAACGTT ['AAC', 'ACG', 'GAA', 'TCG', 'GTT']
# AACGAACGTT

# %%
ACGTTCGA
